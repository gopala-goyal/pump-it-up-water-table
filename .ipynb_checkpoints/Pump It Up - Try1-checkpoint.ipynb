# %% [markdown]
# ## My final submission for Driven Data - Pump It Up Challenge
#
# ### Scored 82.84 with stacked model (XGB+RF) and ranked 4th among 4785 competitors as of March 27th, 2018
#
# ## Driven Data Username: RinzlerTron

# %%
import pandas as pd
import missingno as msno
import numpy as np
from numpy import nan
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt 
from math import radians,cos,sin
import time
from sklearn.preprocessing import LabelEncoder, StandardScaler
from IPython.display import display
from scipy.stats import boxcox
from scipy.stats import norm
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, StratifiedShuffleSplit
# %matplotlib inline   
import warnings  #ignore all the warnings
warnings.filterwarnings('ignore')
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, make_scorer, fbeta_score
#from catboost import Pool, CatBoostClassifier, cv, CatboostIpythonWidget
from itertools import combinations
import xgboost as xgb
from sklearn.cross_validation import cross_val_score as cv_s
from bayes_opt import BayesianOptimization as BayesOpt
import operator
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, StratifiedShuffleSplit
from sklearn.utils import shuffle
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-72be775cbce1> in <module>
#      21 from itertools import combinations
#      22 import xgboost as xgb
# ---> 23 from sklearn.cross_validation import cross_val_score as cv_s
#      24 from bayes_opt import BayesianOptimization as BayesOpt
#      25 import operator
#
# ModuleNotFoundError: No module named 'sklearn.cross_validation'

# %% [markdown]
# # 0. Initial Data Exploration

# %%
train = pd.read_csv('training_set_values.csv')
test = pd.read_csv('test_set_values.csv')
training_labels = pd.read_csv('training_set_labels.csv')

train.shape
# Out:
# (59400, 41)

# %%
test.shape
# Out:
# (14850, 40)

# %%
train.sample(5)
#all latitude longitude values were imputed from external data; so there are no missing or 0 values in longitude and latitude
# Out:
#           id             status_group  amount_tsh date_recorded  \
# 27262  65519               functional       200.0      07-03-11
# 10317  32732  functional needs repair      2400.0      19-03-11
# 26400  19433               functional         0.0      14-10-12
# 15884  39019           non functional         0.0      20-10-12
# 26241   3080               functional       200.0      09-03-11
#
#                        funder  gps_height        installer  longitude  \
# 27262                  Tredep         290              DWE  38.536926
# 10317                   Conce        1413              DWE  34.802631
# 26400         Total Land Care           0  Total land care  32.232042
# 15884                     Hsw        1227              HSW  34.150173
# 26241  Government Of Tanzania         214              DWE  38.718970
#
#        latitude         wpt_name          ...           payment_type  \
# 27262 -5.114065         Kwandege          ...                monthly
# 10317 -8.643798             none          ...               annually
# 26400 -5.086488    Maulid Rashid          ...             on failure
# 15884 -1.716271  Kwa Mzee Matiko          ...                unknown
# 26241 -5.264909          Bombani          ...                monthly
#
#       water_quality quality_group      quantity  quantity_group        source  \
# 27262          soft          good        enough          enough  shallow well
# 10317          soft          good        enough          enough        spring
# 26400          soft          good  insufficient    insufficient  shallow well
# 15884          soft          good        enough          enough  shallow well
# 26241          soft          good  insufficient    insufficient  shallow well
#
#         source_type source_class     waterpoint_type waterpoint_type_group
# 27262  shallow well  groundwater           hand pump             hand pump
# 10317        spring  groundwater  communal standpipe    communal standpipe
# 26400  shallow well  groundwater           hand pump             hand pump
# 15884  shallow well  groundwater           hand pump             hand pump
# 26241  shallow well  groundwater           hand pump             hand pump
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Checking for Missing Data and Visualizing the Spread

# %%
NAs = pd.concat([train.isnull().sum(), test.isnull().sum()], axis=1, keys=['Train', 'Test'])
NAs[NAs.sum(axis=1) > 0]
display(NAs)
# Out:
#                        Train    Test
# amount_tsh                 0     0.0
# basin                      0     0.0
# construction_year          0     0.0
# date_recorded              0     0.0
# district_code              0     0.0
# extraction_type            0     0.0
# extraction_type_class      0     0.0
# extraction_type_group      0     0.0
# funder                  3635   869.0
# gps_height                 0     0.0
# id                         0     0.0
# installer               3655   877.0
# latitude                   0     0.0
# lga                        0     0.0
# longitude                  0     0.0
# management                 0     0.0
# management_group           0     0.0
# num_private                0     0.0
# payment                    0     0.0
# payment_type               0     0.0
# permit                  3056   737.0
# population                 0     0.0
# public_meeting          3334   821.0
# quality_group              0     0.0
# quantity                   0     0.0
# quantity_group             0     0.0
# recorded_by                0     0.0
# region                     0     0.0
# region_code                0     0.0
# scheme_management       3877   969.0
# scheme_name            28166  7092.0
# source                     0     0.0
# source_class               0     0.0
# source_type                0     0.0
# status_group               0     NaN
# subvillage               371    99.0
# ward                       0     0.0
# water_quality              0     0.0
# waterpoint_type            0     0.0
# waterpoint_type_group      0     0.0
# wpt_name                   0     0.0

# %% [markdown]
# ## Checking Initial correlations in Numerical Features

# %%
corr = train.select_dtypes(include = ['float64', 'int64']).iloc[:,1:].corr()
sns.set(font_scale=2)  
sns.heatmap(corr,  linewidths=0.3, square=True)
plt.rcParams["figure.figsize"] = (30,20)
plt.show()

# %% [markdown]
# ## Checking Distribution of Target Variable in Training Data

# %%
sns.countplot('status_group', data = training_labels)
plt.rcParams["figure.figsize"] = (30,30)
plt.show()

# %% [markdown]
# ## The distribution is unequal and we will have to decide on classification metrics for comparing models
#
# - http://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html#the-average-precision-score-in-multi-label-settings

# %% [markdown]
# # 1. Data Cleaning

# %% [markdown]
# ## Inspecting Cardinality of Categorical Data

# %%
cat_df = pd.DataFrame(columns=["Feature", "Cardinality","% Missings"])

total_cardinality = 0

i=0

for col in train.columns:
    if (train[col].dtype == np.object):
        cat_df.loc[i,"Feature"] = col
        cat_df.loc[i,"Cardinality"] = len(train[col].unique())
        total_cardinality += len(train[col].unique())
        pct_of_missing_values = float((len(train[col]) - train[col].count()) / len(train[col]))
        cat_df.loc[i,"% Missings"] = pct_of_missing_values*100
        i+=1

print("Total cardinality of categorical features:",total_cardinality)

display(cat_df)
# Out:
# Total cardinality of categorical features: 66181
#                   Feature Cardinality % Missings
# 0            status_group           3          0
# 1           date_recorded         356          0
# 2                  funder        1898    6.11953
# 3               installer        2146     6.1532
# 4                wpt_name       37400          0
# 5                   basin           9          0
# 6              subvillage       19288   0.624579
# 7                  region          21          0
# 8                     lga         125          0
# 9                    ward        2092          0
# 10         public_meeting           3    5.61279
# 11            recorded_by           1          0
# 12      scheme_management          13    6.52694
# 13            scheme_name        2697    47.4175
# 14                 permit           3    5.14478
# 15        extraction_type          18          0
# 16  extraction_type_group          13          0
# 17  extraction_type_class           7          0
# 18             management          12          0
# 19       management_group           5          0
# 20                payment           7          0
# 21           payment_type           7          0
# 22          water_quality           8          0
# 23          quality_group           6          0
# 24               quantity           5          0
# 25         quantity_group           5          0
# 26                 source          10          0
# 27            source_type           7          0
# 28           source_class           3          0
# 29        waterpoint_type           7          0
# 30  waterpoint_type_group           6          0

# %%
#Combining Training and Testing Data for ease of imputations and feature engineering
combineddf=pd.concat([train,test],axis=0,ignore_index=True)
combineddf.head(5)
# Out:
#    amount_tsh                    basin  construction_year date_recorded  \
# 0      6000.0               Lake Nyasa               1999      14-03-11
# 1         0.0            Lake Victoria               2010      06-03-13
# 2        25.0                  Pangani               2009      25-02-13
# 3         0.0  Ruvuma / Southern Coast               1986      28-01-13
# 4         0.0            Lake Victoria                  0      13-07-11
#
#    district_code extraction_type extraction_type_class extraction_type_group  \
# 0              5         gravity               gravity               gravity
# 1              2         gravity               gravity               gravity
# 2              4         gravity               gravity               gravity
# 3             63     submersible           submersible           submersible
# 4              1         gravity               gravity               gravity
#
#          funder  gps_height          ...                         source  \
# 0         Roman        1390          ...                         spring
# 1       Grumeti        1399          ...           rainwater harvesting
# 2  Lottery Club         686          ...                            dam
# 3        Unicef         263          ...                    machine dbh
# 4   Action In A           0          ...           rainwater harvesting
#
#   source_class           source_type    status_group  subvillage        ward  \
# 0  groundwater                spring      functional    Mnyusi B    Mundindi
# 1      surface  rainwater harvesting      functional     Nyamara       Natta
# 2      surface                   dam      functional     Majengo     Ngorika
# 3  groundwater              borehole  non functional  Mahakamani    Nanyumbu
# 4      surface  rainwater harvesting      functional  Kyanyamisa  Nyakasimbi
#
#   water_quality              waterpoint_type waterpoint_type_group  \
# 0          soft           communal standpipe    communal standpipe
# 1          soft           communal standpipe    communal standpipe
# 2          soft  communal standpipe multiple    communal standpipe
# 3          soft  communal standpipe multiple    communal standpipe
# 4          soft           communal standpipe    communal standpipe
#
#                wpt_name
# 0                  none
# 1              Zahanati
# 2           Kwa Mahundi
# 3  Zahanati Ya Nanyumbu
# 4               Shuleni
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Dropping categories with too few or too many factor levels

# %%
combineddf.drop(['wpt_name',    # too many levels 
    'subvillage',  # too many levels; we have lat and long for location
    'ward',        # too many levels; we have lat and long for location
    'recorded_by', # constant
    'scheme_name', # too many levels
    'num_private', # irrelevant
    'region_code', # too many levels; we have lat and long for location
    'quantity_group', #same as quantity column
    'source_type',   #same as source but with fewer levels
    'waterpoint_type_group', #same as waterpoint
    'payment_type'],   #same as payment
              axis=1, inplace=True)

combineddf.shape
# Out:
# (74250, 30)

# %%
combinedtemp= combineddf['construction_year'].replace(0,nan)
combinedtemp1=combinedtemp.dropna(how='all',axis=0)
combinedtemp1.median()
#We will use this to replace 0's in construction year in the combined df
# Out:
# 2000.0

# %%
combinedtemp2= combineddf['gps_height'].replace(0,nan)
combinedtemp3=combinedtemp2.dropna(how='all',axis=0)
combinedtemp3.median()
#We will use this to replace 0's in gps height in the combined df
# Out:
# 1166.0

# %% [markdown]
# ### Replacing Na's, Extracting Features and Converting Datatypes for better representation

# %%
#Replace Na's with 0 
combineddf['funder'].replace(nan,0, inplace= True)
combineddf['installer'].replace(nan,0, inplace= True)
combineddf['permit'].replace(nan,0, inplace= True)
combineddf['scheme_management'].replace(nan,0, inplace= True)

#contains True or False values
combineddf['public_meeting'].fillna(value=True, inplace=True)

#Replace 0's with arbitrary categories
combineddf['permit'].replace("0","TRUE", inplace= True) #corresponding to 0's almost entirely not pay to use - so let's consider as True
combineddf['public_meeting'].replace("0","TRUE", inplace= True)
combineddf['scheme_management'].replace(0, "Unknown", inplace=True)  #large number of Blanks - cannot fit this into None or Other group
combineddf['funder'].replace(0, "Other", inplace=True)
combineddf['installer'].replace(0, "Other", inplace=True)
combineddf['installer'].replace('-', "Other", inplace=True)
combineddf['construction_year'].replace(0, 2000, inplace=True) #median value for values aside from 0
combineddf['gps_height'].replace(0, 1166, inplace=True)        #median value for values aside from 0

combineddf['date_recorded'] = pd.to_datetime(combineddf['date_recorded'])   #converting date_recorded into number of days since first recorded date
combineddf['date_recorded'] = (combineddf['date_recorded'] - combineddf['date_recorded'].min()) / np.timedelta64(1, 'D')

#Type-conversion
combineddf['population']=combineddf['population'].astype('float64')  #we all float down here         
combineddf['gps_height']=combineddf['gps_height'].astype('float64') 
combineddf['construction_year']=combineddf['construction_year'].astype('float64')
combineddf['amount_tsh']=combineddf['amount_tsh'].astype('float64')

# %% [markdown]
# #### Dropping similar columns and combining similar features

# %%
cross_tab_extraction = pd.crosstab([combineddf.extraction_type, combineddf.extraction_type_group, combineddf.extraction_type_class], combineddf.status_group)
cross_tab_extraction.plot(kind='bar', stacked=True)

# %%
display(cross_tab_extraction)
# Out:
# status_group                                                           functional  \
# extraction_type           extraction_type_group extraction_type_class
# afridev                   afridev               handpump                     1200
# cemo                      other motorpump       motorpump                      45
# climax                    other motorpump       motorpump                       8
# gravity                   gravity               gravity                     16048
# india mark ii             india mark ii         handpump                     1448
# india mark iii            india mark iii        handpump                       44
# ksb                       submersible           submersible                   703
# mono                      mono                  motorpump                    1082
# nira/tanira               nira/tanira           handpump                     5421
# other                     other                 other                        1029
# other - mkulima/shinyanga other handpump        handpump                        0
# other - play pump         other handpump        handpump                       29
# other - rope pump         rope pump             rope pump                     293
# other - swn 81            other handpump        handpump                      120
# submersible               submersible           submersible                  2626
# swn 80                    swn 80                handpump                     2090
# walimi                    other handpump        handpump                       23
# windmill                  wind-powered          wind-powered                   50
#
# status_group                                                           functional needs repair  \
# extraction_type           extraction_type_group extraction_type_class
# afridev                   afridev               handpump                                    42
# cemo                      other motorpump       motorpump                                    9
# climax                    other motorpump       motorpump                                    0
# gravity                   gravity               gravity                                   2701
# india mark ii             india mark ii         handpump                                    79
# india mark iii            india mark iii        handpump                                     1
# ksb                       submersible           submersible                                 26
# mono                      mono                  motorpump                                  129
# nira/tanira               nira/tanira           handpump                                   641
# other                     other                 other                                      206
# other - mkulima/shinyanga other handpump        handpump                                     0
# other - play pump         other handpump        handpump                                     1
# other - rope pump         rope pump             rope pump                                   17
# other - swn 81            other handpump        handpump                                     7
# submersible               submersible           submersible                                227
# swn 80                    swn 80                handpump                                   212
# walimi                    other handpump        handpump                                    12
# windmill                  wind-powered          wind-powered                                 7
#
# status_group                                                           non functional
# extraction_type           extraction_type_group extraction_type_class
# afridev                   afridev               handpump                          528
# cemo                      other motorpump       motorpump                          36
# climax                    other motorpump       motorpump                          24
# gravity                   gravity               gravity                          8031
# india mark ii             india mark ii         handpump                          873
# india mark iii            india mark iii        handpump                           53
# ksb                       submersible           submersible                       686
# mono                      mono                  motorpump                        1654
# nira/tanira               nira/tanira           handpump                         2092
# other                     other                 other                            5195
# other - mkulima/shinyanga other handpump        handpump                            2
# other - play pump         other handpump        handpump                           55
# other - rope pump         rope pump             rope pump                         141
# other - swn 81            other handpump        handpump                          102
# submersible               submersible           submersible                      1911
# swn 80                    swn 80                handpump                         1368
# walimi                    other handpump        handpump                           13
# windmill                  wind-powered          wind-powered                       60

# %%
combineddf.groupby(['extraction_type_class','extraction_type_group'])['extraction_type'].value_counts()
# Out:
# extraction_type_class  extraction_type_group  extraction_type
# gravity                gravity                gravity                      33263
# handpump               afridev                afridev                       2208
#                        india mark ii          india mark ii                 3029
#                        india mark iii         india mark iii                 135
#                        nira/tanira            nira/tanira                  10205
#                        other handpump         other - swn 81                 284
#                                               other - play pump              101
#                                               walimi                          60
#                                               other - mkulima/shinyanga        2
#                        swn 80                 swn 80                        4588
# motorpump              mono                   mono                          3628
#                        other motorpump        cemo                           108
#                                               climax                          41
# other                  other                  other                         8102
# rope pump              rope pump              other - rope pump              572
# submersible            submersible            submersible                   5982
#                                               ksb                           1790
# wind-powered           wind-powered           windmill                       152
# Name: extraction_type, dtype: int64

# %%
#Define function to replace repeating values under common levels within extracting type - make extraction type group obsolete
def clean_values(combineddf, col, values_dict):
    for k, v in values_dict.items():
        combineddf.loc[combineddf[col] == k, col] = v

#Define key-value pairs for replacing        
clean_values(combineddf, 'extraction_type',
    {
        'india mark ii'             : 'india',
        'india mark iii'            : 'india',
        'other - swn 81'            : 'swn',
        'swn 80'                    : 'swn',
        'other - play pump'         : 'other handpump',
        'walimi'                    : 'other handpump',
        'other - mkulima/shinyanga' : 'other handpump',
        'cemo'                      : 'other motorpump',
        'climax'                    : 'other motorpump',
    }
)


#Drop 'extraction_type_group'
combineddf.drop(['extraction_type_group'],axis=1, inplace=True)
combineddf.shape
# Out:
# (74250, 29)

# %%
combineddf.groupby(['extraction_type_class'])['extraction_type'].value_counts()
# Out:
# extraction_type_class  extraction_type
# gravity                gravity              33263
# handpump               nira/tanira          10205
#                        swn                   4872
#                        india                 3164
#                        afridev               2208
#                        other handpump         163
# motorpump              mono                  3628
#                        other motorpump        149
# other                  other                 8102
# rope pump              other - rope pump      572
# submersible            submersible           5982
#                        ksb                   1790
# wind-powered           windmill               152
# Name: extraction_type, dtype: int64

# %%
combineddf.isnull().sum()
# Out:
# amount_tsh                   0
# basin                        0
# construction_year            0
# date_recorded                0
# district_code                0
# extraction_type              0
# extraction_type_class        0
# funder                       0
# gps_height                   0
# id                           0
# installer                    0
# latitude                     0
# lga                          0
# longitude                    0
# management                   0
# management_group             0
# payment                      0
# permit                       0
# population                   0
# public_meeting               0
# quality_group                0
# quantity                     0
# region                       0
# scheme_management            0
# source                       0
# source_class                 0
# status_group             14850
# water_quality                0
# waterpoint_type              0
# dtype: int64

# %%
#Latitude and Longitude to cartesian coordinates
# Assuming Earth as sphere not ellipsoid 
def cartesian_x(lat,lon):
    lat=radians(lat)
    lon=radians(lon)
    R=6371.0
    x = R * cos(lat) * cos(lon)
    return x
def cartesian_y(lat,lon):
    lat=radians(lat)
    lon=radians(lon)
    R=6371.0
    y = R * cos(lat) * sin(lon)
    return y

# extracting cartesian x,y cordinates form latitude and longitude
combineddf['x1']=[cartesian_x(i,j) for i,j in zip(combineddf['latitude'],combineddf['longitude'])]
combineddf['y1']=[cartesian_y(i,j) for i,j in zip(combineddf['latitude'],combineddf['longitude'])]

#Manhattan distance as a new feature
#combineddf['Manhattan_dist'] =(combineddf['x1']).abs() +(combineddf['y1']).abs()

# %%
combineddf.drop(['latitude',    
    'longitude' 
    #,'x1',       
    #'y1'
                ], axis=1, inplace=True)

# %%
display(combineddf['funder'].describe())
# Out:
# count                      74250
# unique                      2141
# top       Government Of Tanzania
# freq                       11299
# Name: funder, dtype: object

# %% [markdown]
# #### Tried to represent Funder and Installer categories as a function of their frequency, but it was not considered as an important feature by multiple models
# #### Hence, reverted to a different representation method

# %%
#def freq_map(x):
#    try:
#        return freq[x]
#    except KeyError:
#        return 0

#freq = combineddf['funder'].value_counts().to_dict()
#combineddf['funder_freq'] = combineddf['funder'].apply(freq_map)

#display(combineddf['funder_freq'].describe())

# %%
#histogram of funder_frequency
#sns.distplot(combineddf['funder_freq'], hist=True, fit=norm)

# %%
#doing box-cox to normalize
#combineddf['funder_freq_BC'] = boxcox(combineddf['funder_freq'] + 1)[0]

#sns.distplot(combineddf['funder_freq_BC'], hist = True, fit=norm)

# %%
#moving on to 'installer' which has similar # of levels

# %%
#display(combineddf['installer'].describe())

# %%
#doing similar feature engineering for Installer
#def freq_map(x):
#    try:
#        return freq[x]
#    except KeyError:
#        return 0

#freq = combineddf['installer'].value_counts().to_dict()
#combineddf['installer_freq'] = combineddf['installer'].apply(freq_map)

#display(combineddf['installer_freq'].describe())

#combineddf['installer_freq_BC'] = boxcox(combineddf['installer_freq'] + 1)[0]

# %%
#dropping duplicated features
#combineddf.drop(['installer_freq',     
#    'installer',  
#    'funder_freq',       
#    'funder'],   
#    axis=1, inplace=True)

# %%
combineddf.select_dtypes(['object'])
# Out:
#                          basin extraction_type extraction_type_class  \
# 0                   Lake Nyasa         gravity               gravity
# 1                Lake Victoria         gravity               gravity
# 2                      Pangani         gravity               gravity
# 3      Ruvuma / Southern Coast     submersible           submersible
# 4                Lake Victoria         gravity               gravity
# 5                      Pangani     submersible           submersible
# 6                     Internal             swn              handpump
# 7              Lake Tanganyika     nira/tanira              handpump
# 8              Lake Tanganyika           india              handpump
# 9                Lake Victoria     nira/tanira              handpump
# 10                 Wami / Ruvu     submersible           submersible
# 11                  Lake Nyasa             swn              handpump
# 12                    Internal     nira/tanira              handpump
# 13                     Pangani         gravity               gravity
# 14                    Internal     nira/tanira              handpump
# 15             Lake Tanganyika             swn              handpump
# 16                      Rufiji         gravity               gravity
# 17                      Rufiji         gravity               gravity
# 18               Lake Victoria           other                 other
# 19                  Lake Nyasa         gravity               gravity
# 20                  Lake Nyasa         gravity               gravity
# 21               Lake Victoria             swn              handpump
# 22                      Rufiji         gravity               gravity
# 23                     Pangani         gravity               gravity
# 24             Lake Tanganyika         gravity               gravity
# 25                     Pangani         gravity               gravity
# 26     Ruvuma / Southern Coast           india              handpump
# 27               Lake Victoria     nira/tanira              handpump
# 28                     Pangani         gravity               gravity
# 29                     Pangani         gravity               gravity
# ...                        ...             ...                   ...
# 74220  Ruvuma / Southern Coast         gravity               gravity
# 74221                  Pangani         gravity               gravity
# 74222  Ruvuma / Southern Coast         gravity               gravity
# 74223               Lake Nyasa         gravity               gravity
# 74224              Wami / Ruvu             swn              handpump
# 74225  Ruvuma / Southern Coast           india              handpump
# 74226          Lake Tanganyika     nira/tanira              handpump
# 74227            Lake Victoria     nira/tanira              handpump
# 74228              Wami / Ruvu           other                 other
# 74229  Ruvuma / Southern Coast         gravity               gravity
# 74230                  Pangani         gravity               gravity
# 74231            Lake Victoria     nira/tanira              handpump
# 74232                  Pangani     submersible           submersible
# 74233               Lake Nyasa         gravity               gravity
# 74234                 Internal         gravity               gravity
# 74235          Lake Tanganyika     nira/tanira              handpump
# 74236                   Rufiji             swn              handpump
# 74237          Lake Tanganyika           india              handpump
# 74238               Lake Nyasa         gravity               gravity
# 74239                  Pangani         gravity               gravity
# 74240               Lake Nyasa         gravity               gravity
# 74241            Lake Victoria             swn              handpump
# 74242          Lake Tanganyika         gravity               gravity
# 74243          Lake Tanganyika           other                 other
# 74244            Lake Victoria     nira/tanira              handpump
# 74245              Wami / Ruvu            mono             motorpump
# 74246                  Pangani     nira/tanira              handpump
# 74247                 Internal         gravity               gravity
# 74248               Lake Nyasa         gravity               gravity
# 74249               Lake Nyasa         gravity               gravity
#
#                          funder             installer               lga  \
# 0                         Roman                 Roman            Ludewa
# 1                       Grumeti               GRUMETI         Serengeti
# 2                  Lottery Club          World vision         Simanjiro
# 3                        Unicef                UNICEF          Nanyumbu
# 4                   Action In A               Artisan           Karagwe
# 5           Mkinga Distric Coun                   DWE            Mkinga
# 6                          Dwsp                  DWSP   Shinyanga Rural
# 7                         Rwssp                   DWE            Kahama
# 8                      Wateraid             Water Aid      Tabora Urban
# 9                   Isingiro Ho               Artisan           Karagwe
# 10                      Private               Private          Mkuranga
# 11                       Danida                DANIDA          Namtumbo
# 12                 World Vision          World vision             Maswa
# 13      Lawatefuka Water Supply  Lawatefuka water sup              Siha
# 14                        Biore                WEDECO             Meatu
# 15                        Rudep                   DWE  Sumbawanga Rural
# 16                       Unicef                   DWE            Njombe
# 17                       Unicef                   DWE            Njombe
# 18                       Hesawa                   DWE           Ukerewe
# 19                       Danida                 Danid            Ludewa
# 20                          Twe                   TWE            Njombe
# 21                         Dwsp                   DWE           Bariadi
# 22                       Unicef                   DWE            Njombe
# 23                          Isf                   ISF              Same
# 24     African Development Bank                   DWE      Kigoma Rural
# 25       Government Of Tanzania                   DWE       Moshi Rural
# 26                       Sobodo           Kilolo Star       Lindi Rural
# 27                       Hesawa                   DWE           Karagwe
# 28       Government Of Tanzania      District council             Rombo
# 29      Lawatefuka Water Supply  Lawatefuka water sup              Siha
# ...                         ...                   ...               ...
# 74220                     Dbfpe                 DBFPE        Nachingwea
# 74221                Ces (gmbh)                   DWE       Moshi Rural
# 74222                       Lga                   LGA            Newala
# 74223                     Other                 Other            Rungwe
# 74224                        Po                    Po            Kilosa
# 74225                 Fin Water             FIN WATER          Nanyumbu
# 74226              World Vision          World vision           Bukombe
# 74227                    Hesawa                HESAWA         Sengerema
# 74228                   Private               Private          Mkuranga
# 74229    Government Of Tanzania            Government            Mbinga
# 74230                      Tcrs                  TCRS              Same
# 74231                    Hesawa                   DWE              Magu
# 74232                      Kkkt                  KKKT              Meru
# 74233                      Kkkt                 Commu            Makete
# 74234                     Kirde                   DWE            Kondoa
# 74235                     Rwssp                   DWE            Kahama
# 74236                     Amref                 AMREF          Mkuranga
# 74237                     Tasaf                 TASAF            Kasulu
# 74238                      Kkkt                 Commu            Makete
# 74239         Devon Aid Korogwe      Local technician           Korogwe
# 74240                 Villagers             Villagers      Songea Rural
# 74241                      Dwsp                   DWE           Bariadi
# 74242                       Isf                   DWE      Kigoma Rural
# 74243                    Oxfarm                OXFARM      Kigoma Rural
# 74244               Netherlands                   DWE             Maswa
# 74245                    Danida                    Da          Bagamoyo
# 74246                      Hiap                  HIAP           Kilindi
# 74247                     Other                 Other     Singida Rural
# 74248                   Germany                   DWE      Songea Rural
# 74249    Government Of Tanzania            Government            Mbinga
#
#              management management_group                payment permit  \
# 0                   vwc       user-group           pay annually  False
# 1                   wug       user-group              never pay   True
# 2                   vwc       user-group         pay per bucket   True
# 3                   vwc       user-group              never pay   True
# 4                 other            other              never pay   True
# 5                   vwc       user-group         pay per bucket   True
# 6                   vwc       user-group              never pay   True
# 7                   wug       user-group                unknown   True
# 8                   vwc       user-group              never pay   True
# 9                   vwc       user-group              never pay   True
# 10     private operator       commercial              never pay  False
# 11                  wug       user-group  pay when scheme fails  False
# 12                  wug       user-group                  other  False
# 13          water board       user-group            pay monthly   True
# 14                  wug       user-group              never pay   True
# 15                  vwc       user-group              never pay  False
# 16                  wua       user-group            pay monthly   True
# 17                  wua       user-group  pay when scheme fails   True
# 18                  vwc       user-group              never pay   True
# 19                  vwc       user-group           pay annually   True
# 20                  vwc       user-group            pay monthly  False
# 21                  wug       user-group                unknown  False
# 22                  wua       user-group              never pay   True
# 23                  vwc       user-group            pay monthly   True
# 24                  vwc       user-group                unknown   True
# 25                  vwc       user-group                unknown   True
# 26                  vwc       user-group            pay monthly  False
# 27                  vwc       user-group              never pay   True
# 28              company       commercial            pay monthly   True
# 29          water board       user-group            pay monthly   True
# ...                 ...              ...                    ...    ...
# 74220               vwc       user-group              never pay  False
# 74221       water board       user-group         pay per bucket   True
# 74222             other            other         pay per bucket  False
# 74223        parastatal       parastatal                unknown      0
# 74224               vwc       user-group              never pay   True
# 74225               vwc       user-group              never pay   True
# 74226               wug       user-group                unknown   True
# 74227               vwc       user-group           pay annually   True
# 74228  private operator       commercial         pay per bucket  False
# 74229               vwc       user-group                unknown   True
# 74230               vwc       user-group              never pay   True
# 74231               vwc       user-group              never pay   True
# 74232               vwc       user-group                unknown  False
# 74233               vwc       user-group           pay annually  False
# 74234               vwc       user-group            pay monthly  False
# 74235               wug       user-group                unknown   True
# 74236               vwc       user-group              never pay  False
# 74237               vwc       user-group           pay annually  False
# 74238               vwc       user-group           pay annually  False
# 74239             other            other              never pay  False
# 74240               vwc       user-group              never pay   True
# 74241               wug       user-group                unknown  False
# 74242               vwc       user-group            pay monthly   True
# 74243               vwc       user-group              never pay  False
# 74244               wug       user-group                  other  False
# 74245               vwc       user-group              never pay   True
# 74246               vwc       user-group           pay annually  False
# 74247               vwc       user-group              never pay      0
# 74248               vwc       user-group              never pay   True
# 74249               vwc       user-group              never pay   True
#
#       quality_group      quantity       region scheme_management  \
# 0              good        enough       Iringa               VWC
# 1              good  insufficient         Mara             Other
# 2              good        enough      Manyara               VWC
# 3              good           dry       Mtwara               VWC
# 4              good      seasonal       Kagera           Unknown
# 5             salty        enough        Tanga               VWC
# 6              good        enough    Shinyanga               VWC
# 7             milky        enough    Shinyanga           Unknown
# 8             salty      seasonal       Tabora               VWC
# 9              good        enough       Kagera           Unknown
# 10            salty        enough        Pwani  Private operator
# 11             good  insufficient       Ruvuma               WUG
# 12             good        enough    Shinyanga               WUG
# 13             good        enough  Kilimanjaro       Water Board
# 14             good        enough    Shinyanga               WUG
# 15             good        enough        Rukwa               VWC
# 16             good           dry       Iringa               WUA
# 17             good           dry       Iringa               WUA
# 18            milky  insufficient       Mwanza           Unknown
# 19             good        enough       Iringa               VWC
# 20             good        enough       Iringa               VWC
# 21          unknown       unknown    Shinyanga               WUG
# 22             good        enough       Iringa               WUA
# 23             good        enough  Kilimanjaro   Water authority
# 24             good        enough       Kigoma               VWC
# 25             good        enough  Kilimanjaro               VWC
# 26             good        enough        Lindi               VWC
# 27             good        enough       Kagera           Unknown
# 28             good  insufficient  Kilimanjaro           Company
# 29             good        enough  Kilimanjaro       Water Board
# ...             ...           ...          ...               ...
# 74220          good      seasonal        Lindi               VWC
# 74221          good        enough  Kilimanjaro       Water Board
# 74222          good  insufficient       Mtwara             Other
# 74223          good        enough        Mbeya        Parastatal
# 74224          good  insufficient     Morogoro               VWC
# 74225          good  insufficient       Mtwara               VWC
# 74226          good        enough    Shinyanga               WUG
# 74227          good        enough       Mwanza               VWC
# 74228         salty        enough        Pwani  Private operator
# 74229          good        enough       Ruvuma               VWC
# 74230          good  insufficient  Kilimanjaro   Water authority
# 74231         salty        enough       Mwanza               VWC
# 74232      fluoride        enough       Arusha               VWC
# 74233          good        enough       Iringa               VWC
# 74234          good  insufficient       Dodoma               VWC
# 74235          good        enough    Shinyanga           Unknown
# 74236          good        enough        Pwani               VWC
# 74237          good        enough       Kigoma   Water authority
# 74238          good        enough       Iringa               VWC
# 74239          good  insufficient        Tanga             Other
# 74240          good        enough       Ruvuma               VWC
# 74241          good        enough    Shinyanga               WUG
# 74242          good        enough       Kigoma               WUG
# 74243          good        enough       Kigoma   Water authority
# 74244          good        enough    Shinyanga               WUG
# 74245          good        enough        Pwani               VWC
# 74246         salty  insufficient        Tanga               VWC
# 74247          good  insufficient      Singida               VWC
# 74248          good  insufficient       Ruvuma               VWC
# 74249          good           dry       Ruvuma               VWC
#
#                      source source_class             status_group  \
# 0                    spring  groundwater               functional
# 1      rainwater harvesting      surface               functional
# 2                       dam      surface               functional
# 3               machine dbh  groundwater           non functional
# 4      rainwater harvesting      surface               functional
# 5                     other      unknown               functional
# 6               machine dbh  groundwater           non functional
# 7              shallow well  groundwater           non functional
# 8               machine dbh  groundwater           non functional
# 9              shallow well  groundwater               functional
# 10              machine dbh  groundwater               functional
# 11             shallow well  groundwater               functional
# 12             shallow well  groundwater               functional
# 13                   spring  groundwater               functional
# 14             shallow well  groundwater               functional
# 15              machine dbh  groundwater               functional
# 16                    river      surface           non functional
# 17                    river      surface           non functional
# 18                   spring  groundwater  functional needs repair
# 19                   spring  groundwater               functional
# 20                   spring  groundwater               functional
# 21             shallow well  groundwater               functional
# 22                    river      surface  functional needs repair
# 23                    river      surface               functional
# 24                   spring  groundwater               functional
# 25                   spring  groundwater  functional needs repair
# 26              machine dbh  groundwater               functional
# 27             shallow well  groundwater               functional
# 28                   spring  groundwater           non functional
# 29                   spring  groundwater               functional
# ...                     ...          ...                      ...
# 74220  rainwater harvesting      surface                      NaN
# 74221                 river      surface                      NaN
# 74222                spring  groundwater                      NaN
# 74223                spring  groundwater                      NaN
# 74224          shallow well  groundwater                      NaN
# 74225           machine dbh  groundwater                      NaN
# 74226          shallow well  groundwater                      NaN
# 74227          shallow well  groundwater                      NaN
# 74228           machine dbh  groundwater                      NaN
# 74229                spring  groundwater                      NaN
# 74230                spring  groundwater                      NaN
# 74231          shallow well  groundwater                      NaN
# 74232           machine dbh  groundwater                      NaN
# 74233                spring  groundwater                      NaN
# 74234                spring  groundwater                      NaN
# 74235          shallow well  groundwater                      NaN
# 74236          shallow well  groundwater                      NaN
# 74237           machine dbh  groundwater                      NaN
# 74238                spring  groundwater                      NaN
# 74239                spring  groundwater                      NaN
# 74240                 river      surface                      NaN
# 74241          shallow well  groundwater                      NaN
# 74242                 river      surface                      NaN
# 74243                spring  groundwater                      NaN
# 74244          shallow well  groundwater                      NaN
# 74245                 river      surface                      NaN
# 74246          shallow well  groundwater                      NaN
# 74247                   dam      surface                      NaN
# 74248                 river      surface                      NaN
# 74249                spring  groundwater                      NaN
#
#             water_quality              waterpoint_type
# 0                    soft           communal standpipe
# 1                    soft           communal standpipe
# 2                    soft  communal standpipe multiple
# 3                    soft  communal standpipe multiple
# 4                    soft           communal standpipe
# 5                   salty  communal standpipe multiple
# 6                    soft                    hand pump
# 7                   milky                    hand pump
# 8                   salty                    hand pump
# 9                    soft                    hand pump
# 10                  salty                        other
# 11                   soft                    hand pump
# 12                   soft                    hand pump
# 13                   soft           communal standpipe
# 14                   soft                    hand pump
# 15                   soft                    hand pump
# 16                   soft           communal standpipe
# 17                   soft           communal standpipe
# 18                  milky                        other
# 19                   soft           communal standpipe
# 20                   soft           communal standpipe
# 21                unknown                    hand pump
# 22                   soft           communal standpipe
# 23                   soft           communal standpipe
# 24                   soft              improved spring
# 25                   soft           communal standpipe
# 26                   soft                    hand pump
# 27                   soft                    hand pump
# 28                   soft           communal standpipe
# 29                   soft           communal standpipe
# ...                   ...                          ...
# 74220                soft           communal standpipe
# 74221                soft           communal standpipe
# 74222                soft           communal standpipe
# 74223                soft           communal standpipe
# 74224                soft                    hand pump
# 74225                soft                    hand pump
# 74226                soft                    hand pump
# 74227                soft                    hand pump
# 74228               salty                        other
# 74229                soft           communal standpipe
# 74230                soft           communal standpipe
# 74231               salty                    hand pump
# 74232  fluoride abandoned           communal standpipe
# 74233                soft           communal standpipe
# 74234                soft           communal standpipe
# 74235                soft                    hand pump
# 74236                soft                    hand pump
# 74237                soft                    hand pump
# 74238                soft           communal standpipe
# 74239                soft           communal standpipe
# 74240                soft           communal standpipe
# 74241                soft                    hand pump
# 74242                soft  communal standpipe multiple
# 74243                soft                        other
# 74244                soft                    hand pump
# 74245                soft           communal standpipe
# 74246               salty                    hand pump
# 74247                soft           communal standpipe
# 74248                soft           communal standpipe
# 74249                soft           communal standpipe
#
# [74250 rows x 19 columns]

# %%
#Listing Categorical columns for label encoding
cat_cols=combineddf.select_dtypes(include=['object']).columns.values.tolist()
cat_cols
# Out:
# ['basin',
#  'extraction_type',
#  'extraction_type_class',
#  'funder',
#  'installer',
#  'lga',
#  'management',
#  'management_group',
#  'payment',
#  'permit',
#  'quality_group',
#  'quantity',
#  'region',
#  'scheme_management',
#  'source',
#  'source_class',
#  'status_group',
#  'water_quality',
#  'waterpoint_type']

# %% [markdown]
# ### Treating Categorical and Numerical Features

# %%
#Listing numerical columns for scaling
num_cols=combineddf.select_dtypes(include=['int64', 'float64']).columns.values.tolist()
num_cols
# Out:
# ['amount_tsh',
#  'construction_year',
#  'date_recorded',
#  'district_code',
#  'gps_height',
#  'id',
#  'population',
#  'x1',
#  'y1']

# %%
#Listing Categorical columns for label encoding
cols=('basin',
 'extraction_type',
 'extraction_type_class',
 'lga',
 'management',
 'management_group',
 'payment',
 'permit',
 'quality_group',
 'quantity',
 'region',
 'scheme_management',
 'source',
 'source_class',
 'water_quality',
 'waterpoint_type',
 'public_meeting', 
 'funder', 
 'installer')  #need to encode funder and installer to pass through models

# Applying Label Encoding
for c in cols:
    lbl = LabelEncoder() 
    lbl.fit(list(combineddf[c].values)) 
    combineddf[c] = lbl.transform(list(combineddf[c].values))
    
###########################
#funder and installer had too many levels; going back to format them as function of frequency
###########################
combineddf.shape
# Out:
# (74250, 29)

# %%
combineddf.dtypes
# Out:
# amount_tsh               float64
# basin                      int64
# construction_year        float64
# date_recorded            float64
# district_code              int64
# extraction_type            int64
# extraction_type_class      int64
# funder                     int64
# gps_height               float64
# id                         int64
# installer                  int64
# lga                        int64
# management                 int64
# management_group           int64
# payment                    int64
# permit                     int64
# population               float64
# public_meeting             int64
# quality_group              int64
# quantity                   int64
# region                     int64
# scheme_management          int64
# source                     int64
# source_class               int64
# status_group              object
# water_quality              int64
# waterpoint_type            int64
# x1                       float64
# y1                       float64
# dtype: object

# %%
# Scaling numeric features
scaler = StandardScaler()
numeric_features = combineddf.select_dtypes(include=np.float64)

scaler.fit(numeric_features)
combineddf[numeric_features.columns] = scaler.transform(combineddf[numeric_features.columns])

display(combineddf[numeric_features.columns].head())
# Out:
#    amount_tsh  construction_year  date_recorded  gps_height  population  \
# 0    1.954529           0.102017      -1.158258    0.641710   -0.152310
# 1   -0.109637           1.186609       1.257651    0.659671    0.210683
# 2   -0.101036           1.088010       0.966076   -0.763253    0.147000
# 3   -0.109637          -1.179773       0.882769   -1.607428   -0.260572
# 4   -0.109637           0.200617      -0.798252    0.194676   -0.383692
#
#          x1        y1
# 0 -0.166716 -0.180223
# 1  0.342934 -0.051832
# 2 -0.740788  1.003381
# 3 -1.621649  1.106209
# 4  1.588009 -1.499332

# %%
#Encoding status_group of train to pass it through our models
y = training_labels.status_group
LEncoder = LabelEncoder()
LEncoder.fit(y)
labels = LEncoder.transform(y)
print(LEncoder.classes_)
# Out:
# ['functional' 'functional needs repair' 'non functional']

# %%
display(labels)
# Out:
# array([0, 0, 2, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# #### Preparing Training, Validation and Test Data for Modeling

# %%
x = combineddf[:train.shape[0]]
test_data = combineddf[train.shape[0]:]

# %%
x.to_csv("pythonoutputtrain.csv")
test_data.to_csv("pythonoutputtest.csv")

# %%
x.drop(['id'],axis=1, inplace=True)
x.drop(['status_group'],axis=1, inplace=True)

# %%
test_data.drop(['id'],axis=1, inplace=True)

# %%
temp_forid = combineddf[train.shape[0]:]
test_ids= temp_forid.id

# %%
# Split training and validation data
x, labels = shuffle(x, labels, random_state= 10)
X_train, X_valid, y_train, y_valid = train_test_split(x, labels, train_size=0.8, random_state=10)

# %% [markdown]
# # 2. Building Models with prepared data
#
# ## Base Random Forest Model

# %%
RF_model = RandomForestClassifier(n_estimators=1000)
RF_model.fit(X_train, y_train)
y_pred = RF_model.predict(X_valid)

# %%
#Accuracy on validation data
acc=accuracy_score(y_valid, y_pred)
fscore = fbeta_score(y_valid, y_pred, average='weighted', beta=0.5)
print('RF Accuracy:', acc)
print('RF Fbeta score:', fscore)

#this is my base model - score was ~80.1 with this on the leaderboard.Not going with this for final submission unless I do an ensemble; used it to infer feature importances
#manhattan distance has lower importance than latitude longitude (based on past trials)
#but it's represented better, so will keep manhattan distance as is; plus CatBoost performs better with this feature than lat and long

#Finally decided to remove Manhattan distance and just keep the cartesian coordinates, because catboost did not perform well
# Out:
# RF Accuracy: 0.8058922558922559
# RF Fbeta score: 0.799621972352458

# %%
features = RF_model.feature_importances_
imp_features = np.argsort(features)[::-1]
k = 20
print(x[:train.shape[0]].columns[imp_features[:10]])
series_imp_features = pd.Series(features[imp_features[:k]], x[:train.shape[0]].columns[imp_features[:k]])
series_imp_features.plot(kind='bar')
# Out:
# Index(['x1', 'y1', 'quantity', 'date_recorded', 'gps_height',
#        'waterpoint_type', 'construction_year', 'population', 'funder',
#        'extraction_type_class'],
#       dtype='object')

# %% [markdown]
# ## CatBoost Model

# %%
cbc= CatBoostClassifier(
    learning_rate=0.1,
    loss_function='MultiClass', 
    calc_feature_importance=True,
    eval_metric='Accuracy',
    od_pval=0.01,
    random_seed=10
)

# %%
cbc.fit(X_train, y_train)

# %%
#Validation score with CatBoost
print('Train: {:.4f}'.format(
    cbc.score(X_train, y_train)
))
# Out:
# Train: 0.8314

# %%
x.columns.values
# Out:
# array(['amount_tsh', 'basin', 'construction_year', 'date_recorded',
#        'district_code', 'extraction_type', 'extraction_type_class',
#        'gps_height', 'lga', 'management', 'management_group', 'payment',
#        'permit', 'population', 'public_meeting', 'quality_group',
#        'quantity', 'region', 'scheme_management', 'source',
#        'source_class', 'water_quality', 'waterpoint_type',
#        'Manhattan_dist', 'funder_freq_BC', 'installer_freq_BC'],
#       dtype=object)

# %%
ctrs= ['basin', 'construction_year',
       'district_code', 'extraction_type', 'extraction_type_class',
        'lga', 'management', 'management_group', 'payment',
       'permit', 'public_meeting', 'quality_group',
       'quantity', 'region', 'scheme_management', 'source',
       'source_class', 'water_quality', 'waterpoint_type', 
       'funder', 'installer'] #adding funder and installer as categories again; representing them as function of frequencies did not help with catboost

# %%
ctrs_indexes = []
for i, v in enumerate(features):
    if v in ctrs:
        ctrs_indexes.append(i)

# %%
#fitting whole train set
cbc = CatBoostClassifier(
    learning_rate=0.1,
    loss_function='MultiClass', 
    eval_metric='Accuracy',
).fit(x, labels, cat_features= ctrs_indexes)   #got over-fitted model when features was not specified; possibly because it considers everything as a category by default

# %%
def submit(pred, name='ans_catboost'):
    y_pred = LEncoder.inverse_transform(pred.astype(int))
    ans_catboost = pd.DataFrame({'id': test_ids, 'status_group': y_pred.ravel()})
    ans_catboost.to_csv('submissions/' + name + '.csv', index=False)

# %%
submit(cbc.predict(test_data))  

#tried hyperparameter optimization; catboost does not perform well for multiclass, especially with mixed categorical and numerical types
#level of tuning required outweighed by performance and ease of use of other base models
#even RandomForest performed better in this case, so moving onto XGBoost

# %% [markdown]
# ### XGBoost - Base Model - scored 82.01 on Leaderboard; Ensemble of RF, XGB scored highest at 82.84

# %%
param = {'booster': 'gbtree',
        'obective': 'multi:softmax',
        'eta': 0.025,
        'max_depth': 23,
        'colsample_bytree': 0.4,
        'silent': 1,
        'eval_metric': 'mlogloss',
        'num_class': 3
        }

# %%
train_dmatrix = xgb.DMatrix(x, label=labels, missing=np.nan)

# %%
clf = xgb.train(param, dtrain=train_dmatrix, num_boost_round=400, maximize=False)

# %%
test_data.drop(['status_group'],axis=1, inplace=True)
test_dmatrix = xgb.DMatrix(test_data, missing=np.nan)

# %%
def submit(pred, name='ans_xgb'):
    y_pred = LEncoder.inverse_transform(pred.astype(int))
    ans_xgb = pd.DataFrame({'id': test_ids, 'status_group': y_pred.ravel()})
    ans_xgb.to_csv('submissions/' + name + '.csv', index=False)

# %%
submit(clf.predict(test_dmatrix))

# %%
importances = clf.get_fscore()
importances = sorted(importances.items(), key=operator.itemgetter(1))

# %%
temp = pd.DataFrame(importances, columns=['feature', 'fscore'])
temp['fscore'] = temp['fscore'] / temp['fscore'].sum()
plt.figure()
temp.plot()
temp.plot(kind='barh', x='feature', y='fscore', legend=False, figsize=(6, 10))
plt.title('XGBoost Feature Importance')
plt.xlabel('relative importance')
# Out:
# Text(0.5,0,'relative importance')

# %% [markdown]
# # Used Bayesian-optimization for hyperparameter search
#
# #Did this on Cloud Datalab on n1-highcpu-16; but maxed out the utilization so was only able to take a few parameters from the entire grid
#
#
# Step |   Time |      Value |   colsample_bytree |     gamma |   learning_rate |   max_depth |   min_child_weight |   n_estimators |   reg_alpha |   reg_lambda |   subsample |
#
#   25 | 06m36s |    0.80988 |             0.3645 |    0.0106 |          0.0622 |     21.2614 |            18.4682 |       596.4880 |      0.0463 |       8.1202 |      0.9928 |
#
#
#   31 | 05m26s |    0.81015 |             0.6716 |    0.0354 |          0.0486 |     19.3704 |            19.2455 |       591.0918 |      6.0458 |       8.8225 |      0.9842 |

# %%
#Defining function for optimizing XGBoost - can also do this for other models like RF
def xgbcv(max_depth,  
          learning_rate, 
          n_estimators,
          min_child_weight,
          gamma,
          subsample,
          colsample_bytree,
          reg_alpha, 
          reg_lambda,
          silent=True):
    return cv_s(xgb.XGBClassifier(max_depth=int(max_depth),
                                 learning_rate=learning_rate,
                                 n_estimators=int(n_estimators),
                                 gamma=gamma,
                                 reg_alpha=reg_alpha,
                                 min_child_weight=min_child_weight,
                                 objective='multi:softmax'),
                    x,
                    labels,
                    "accuracy",
                    cv=4).mean() 

##Setting range of parameters for optimization
xgboostBO = BayesOpt(xgbcv,
                                 {
                                  'max_depth': (4,23),
                                  'learning_rate': (0.01, 0.2),
                                  'n_estimators': (200,600),
                                  'gamma': (0.01, 10),
                                  'min_child_weight': (1,40),
                                  'subsample': (0.2, 1),
                                  'colsample_bytree' :(0.2, 1),
                                  'reg_alpha':(0, 10),
                                  'reg_lambda':(0, 10)
                                  })

# %%
print ("Start Optimization of Main Model")
xgboostBO.maximize(init_points=10,n_iter=110, xi=0.0,  acq="poi")

# %%
#Best parameters from Bayes-opt for accuracy as a metric
param = {
                  'max_depth' : 19,
                  'learning_rate': 0.0486,
                  #'n_estimators': 591,  #removed and mentioned as num_boost_round; same thing
                  'gamma': 0.0354,
                  'min_child_weight': 19.2455,
                  'subsample': 0.9842,
                  'colsample_bytree': 0.6716,
                  'reg_alpha': 6.0458,
                  'objective':'multi:softmax',
                  'num_class': 3,
                  'eval_metric': 'mlogloss'
        }

# %%
clf_final = xgb.train(param, dtrain=train_dmatrix, num_boost_round=591, maximize=False)

# %%
def submit(pred, name='ans_xgb_final'):
    y_pred = LEncoder.inverse_transform(pred.astype(int))
    ans_xgb_final = pd.DataFrame({'id': test_ids, 'status_group': y_pred.ravel()})
    ans_xgb_final.to_csv('submissions/' + name + '.csv', index=False)

# %%
submit(clf.predict(test_dmatrix))

# %%
importances = clf_final.get_fscore()
importances = sorted(importances.items(), key=operator.itemgetter(1))

# %%
temp = pd.DataFrame(importances, columns=['feature', 'fscore'])
temp['fscore'] = temp['fscore'] / temp['fscore'].sum()
plt.figure()
temp.plot()
temp.plot(kind='barh', x='feature', y='fscore', legend=False, figsize=(6, 10))
plt.title('XGBoost Feature Importance')
plt.xlabel('relative importance')
# Out:
# Text(0.5,0,'relative importance')

# %% [markdown]
# # Results:
# - Here, I've compared resuts of individual models.
#
# - The best model obtained was by manually stacking XGBoost and RF in excel and it scored 82.84.
#
# - f-score is not the best metric for comparison here (because of unequal classes) as observed through the Base XGBoost and Optimized one, where importance of features completely shifts based on evaluation metric and parameters.
#
# - There are clear differences between different models optimized for different evaluation metrics.
#
# - Because of this, I conclude that the best possible model for this case is a Stacked one with multiple models;
#   with Bayesian Optimization done for Bagging and Boosting models, eg: both RF and XGBoost, under evaluation metrics - Accuracy and Log Loss
#
# Other observations:
# - Training and validating a single configuration often takes several hours with Bayesian Optimization, which limits the achievable performance, especially on limited availability of processing power.
